# %% [markdown]
# ## 데이터 획득
#
# * api 사용
# * naver open api를 활용
# * urllib.request 모듈을 사용하여 통신처리후 JSON 파싱을 통한 데이터 추출

# %%
import urllib.request
import os
import sys

# %% [markdown]
# #### naver API 사용을 위한 키

# %%
Client_ID = '_kYGPWLxEKgbDV0v7Kn3'
Secret    = 'FNDu62I5Md'

# %% [markdown]
# * 통신할 URL 정의
# * parameter 정의 (get 방식 or post 방식에 맞춰 구성)
# * header에 위에서 정의한 키 및 응답 데이터 포멧에 대한 구성 추가
# * 통신 -> 응답 코드를 확인 : 200번 경우(성공) -> 응답데이터에서 json 데이터획득
# * json데이터에서 [가공 및 전처리는 일단 배제] 데이터를 적제(csv or xls or ddatabase)

# %%
# 네이버 통합 검색어 트렌드 조회 URL
url = "https://openapi.naver.com/v1/datalab/search"
url
# Out:
# 'https://openapi.naver.com/v1/datalab/search'

# %%
body = '{"startDate":"2019-07-09","endDate":"2019-08-06","timeUnit":"month","keywordGroups":[{"groupName":"대한민국","keywords":["대한민국","korean"]},{"groupName":"일본","keywords":["일본","japan"]}],"device":"pc","ages":["3","4"],"gender":"f"}';
body
# Out:
# '{"startDate":"2019-07-09","endDate":"2019-08-06","timeUnit":"month","keywordGroups":[{"groupName":"대한민국","keywords":["대한민국","korean"]},{"groupName":"일본","keywords":["일본","japan"]}],"device":"pc","ages":["3","4"],"gender":"f"}'

# %%
# 통신 객체 생성
request = urllib.request.Request(url)
# 헤더 설정
request.add_header("X-Naver-Client-Id", Client_ID)
request.add_header("X-Naver-Client-Secret", Secret)
request.add_header("Content-Type","application/json")

# %%
# 실제 통신 : post방식
# 한글 데이터를 그대로 전송하면 오류 발생 => body.encode("utf-8") 처리
response = urllib.request.urlopen(request, data=body.encode("utf-8"))

# %%
response

# %%
# 응답 코드가 정상이면
rescode = response.getcode()
if(rescode==200):
    # 실제 응답 데이터를 획득
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {"startDate":"2019-07-01","endDate":"2019-08-08","timeUnit":"month","results":[{"title":"대한민국","keywords":["대한민국","korean"],"data":[{"period":"2019-07-01","ratio":17.93314},{"period":"2019-08-01","ratio":4.72583}]},{"title":"일본","keywords":["일본","japan"],"data":[{"period":"2019-07-01","ratio":100},{"period":"2019-08-01","ratio":34.78968}]}]}

# %%
# 뉴스 검색
news_url = 'https://openapi.naver.com/v1/search/news.json'
news_url
# Out:
# 'https://openapi.naver.com/v1/search/news.json'

# %%
# 파라미터
keyword    = urllib.parse.quote('아베')
news_param = 'query=%s&display=%s&start=%s&sort=%s' % (keyword, 10, 1, 'date')
news_param
# Out:
# 'query=%EC%95%84%EB%B2%A0&display=10&start=1&sort=date'

# %%
url = '%s?%s' % (news_url, news_param)
url
# Out:
# 'https://openapi.naver.com/v1/search/news.json?query=%EC%95%84%EB%B2%A0&display=10&start=1&sort=date'

# %%
# 통신 객체 생성
request = urllib.request.Request(url)
# 헤더 설정
request.add_header("X-Naver-Client-Id", Client_ID)
request.add_header("X-Naver-Client-Secret", Secret)

# %%
# 통신
response = urllib.request.urlopen(request)

# %%
# 응답 코드가 정상이면
rescode = response.getcode()
if(rescode==200):
    # 실제 응답 데이터를 획득
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# "lastBuildDate": "Thu, 08 Aug 2019 11:38:22 +0900",
# "total": 367987,
# "start": 1,
# "display": 10,
# "items": [
# {
# "title": "美 전문가 &quot;한일 분쟁 해결 위해 트럼프 직접 개입해야&quot;",
# "originallink": "https://www.ytn.co.kr/_ln/0104_201908081133308835",
# "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=104&oid=052&aid=0001328713",
# "description": "러시아로 '전향'하는 상황을 막아야 한다고 강조했습니다. 또한, 현 상황의 악화를 막기 위해 트럼프 대통령이 개인적으로 문재인 대통령과 <b>아베</b> 총리에게 추가 확대 행동을 자제하도록 촉구해야 한다고 강조했습니다.",
# "pubDate": "Thu, 08 Aug 2019 11:33:00 +0900"
#
# },
# {
# "title": "민예총 &quot;<b>아베</b>정권 사죄 그날까지 항일예술로 싸워 나갈 것&quot;",
# "originallink": "http://www.headlinejeju.co.kr/?mod=news&act=articleView&idxno=369698",
# "link": "http://www.headlinejeju.co.kr/?mod=news&act=articleView&idxno=369698",
# "description": "사단법인 한국민족예술단체총연합회과 사단법인 제주민예총은 8일 성명을 내고 &quot;일본 <b>아베</b> 정부의 경제... 것&quot;이라며 &quot;<b>아베</b>정권이 사죄하고 민주주의를 회복하는 그날까지 싸울 것&quot;이라고 밝혔다. 이어 &quot;한국 민족예술인은... ",
# "pubDate": "Thu, 08 Aug 2019 11:32:00 +0900"
#
# },
# {
# "title": "나경원 '우리 일본' 발언에 여야 한목소리로 비판…장제원 ''우리 정치 참 좁...",
# "originallink": "http://www.topstarnews.net/news/articleView.html?idxno=655891",
# "link": "http://www.topstarnews.net/news/articleView.html?idxno=655891",
# "description": "이전에 나 원내대표가 <b>아베</b> 정부의 '기 살리기'에 몰두했다는 지적도 이어졌다. 바른미래당 김정화 대변인은... 더불어 이전에 나 원내대표가 이전에 발언한 내용과 관련해서 그를 '나베(나경원+<b>아베</b>)', 친일파 등으로... ",
# "pubDate": "Thu, 08 Aug 2019 11:31:00 +0900"
#
# },
# {
# "title": "[전문]서울시 2부시장 &quot;행안부 요구 대부분 수용…차질없이 진행토록 최선&quot;",
# "originallink": "http://www.edaily.co.kr/news/newspath.asp?newsid=02719126622585352",
# "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=018&aid=0004440997",
# "description": "지금 대한민국은, 역사에 대한 반성 없는 일본 <b>아베</b>정부의 부당한 경제보복에 문재인 대통령과 더불어 온 국민이 각자의 자리에서 총성 없는 전쟁을 하고 있다. 이런 시기에 광화문광장재구조화 사업은 불의에 맞섰던... ",
# "pubDate": "Thu, 08 Aug 2019 11:30:00 +0900"
#
# },
# {
# "title": "&quot;원전사고 정보 공개하라&quot;...'방사능 부메랑' 맞는 日",
# "originallink": "https://view.asiae.co.kr/article/2019080811202604033",
# "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=104&oid=277&aid=0004515534",
# "description": "나아가 국제환경단체 그린피스의 숀 버니 수석 원자력 전문가는 '이코노미스트'에 기고한 글을 통해 &quot;<b>아베</b> 내각과 도쿄전력이 후쿠시마 제1 원전에 쌓인 방사성 오염수 100만t 이상을 태평양에 방류하려고 한다&quot;며 &quot;이... ",
# "pubDate": "Thu, 08 Aug 2019 11:30:00 +0900"
#
# },
# {
# "title": "심상정 정의당 대표 부산 방문",
# "originallink": "http://news.knn.co.kr/news/todaynews_read.asp?etime=2019080700067&userid=jskil&newsgubun=politics",
# "link": "http://news.knn.co.kr/news/todaynews_read.asp?etime=2019080700067&userid=jskil&newsgubun=politics",
# "description": "심상정 대표는 일본영사관 인근 평화의 소녀상 앞에서 <b>아베</b> 규탄 정당연설회를 갖고, 한일군사정보보호협정 파기등 한일관계 재정립을 요구했습니다. 또 1965년 한일협정에서 비롯된 불평등한 과거사와 제도를 이번... ",
# "pubDate": "Thu, 08 Aug 2019 11:30:00 +0900"
#
# },
# {
# "title": "[뉴스클릭] - <b>아베</b> 보좌관, &quot;한국은 과거 매춘 관광국&quot;",
# "originallink": "http://news.knn.co.kr/news/todaynews_read.asp?etime=2019080700069&userid=yellowtiger&newsgubun=society",
# "link": "http://news.knn.co.kr/news/todaynews_read.asp?etime=2019080700069&userid=yellowtiger&newsgubun=society",
# "description": "#정치면 <b>아베</b> 총리의 측근인 에토 세이이치 총리 보좌관이 일본을 방문한 여야 의원들에게 한국은 과거 매춘 관광국이라는 취지의 발언을 해 충격을 주고 있습니다. 한일관계에 대해 편하게 논의하자며 주선한 자리에서... ",
# "pubDate": "Thu, 08 Aug 2019 11:30:00 +0900"
#
# },
# {
# "title": "MBC 기자 폭행한 이영훈을 보면서",
# "originallink": "http://www.pressian.com/news/article.html?no=252416&utm_source=naver&utm_medium=search",
# "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=110&oid=002&aid=0002099809",
# "description": "SNS 공간만 해도 문재인 정부의 상식 부재를 비하하고 <b>아베</b> 정부의 합리성을 옹호하는 이른바 “지식인”들의 글이 서캐처럼 바글바글하다. 하지만 오늘 스마트폰 화면에 떠오른 할머니의 얼굴. 마이크 들고 외치는 저... ",
# "pubDate": "Thu, 08 Aug 2019 11:29:00 +0900"
#
# },
# {
# "title": "평화의 소녀상 앞에 무릎꿇은 <b>아베</b> 퍼포먼스",
# "originallink": "http://www.newsis.com/view/?id=NISI20190808_0015479542",
# "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=102&oid=003&aid=0009390287",
# "description": "광주 북구 평화인간띠잇기추진위원회가 8일 북구청 평화의 소녀상 광장에서 <b>아베</b> 신조 일본 총리를 규탄하는 퍼포먼스를 하고 있다. 2019.08.08.",
# "pubDate": "Thu, 08 Aug 2019 11:29:00 +0900"
#
# },
# {
# "title": "3년 전 겨울 소녀상 지키던 대학생 &quot;한일문제, 일본 시민과 연대 필요&quot;",
# "originallink": "https://view.asiae.co.kr/article/2019080811293569876",
# "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=102&oid=277&aid=0004515532",
# "description": "이 대표는 한일갈등은 당연히 <b>아베</b> 신조 일본 총리의 책임이라고 강조한다. 그는 &quot;한일 청구권협정과 위안부... 역시 <b>아베</b> 정부의 실책이라고 생각한다&quot;고 했다. 일본에 대한 분노가 가득한 상황에서 일본 제품... ",
# "pubDate": "Thu, 08 Aug 2019 11:29:00 +0900"
#
# }
# ]
# }

# %%
tmp = response_body.decode('utf-8')

# %%
type(tmp)
# Out:
# str

# %%
# 원하는 데이터를 추출 => 파싱 => xml, json  같은 형식을 취해야한다

# %%
response = urllib.request.urlopen(request)

# %%
import json

# %%
tmp = json.load(response)
tmp
# Out:
# {'lastBuildDate': 'Thu, 08 Aug 2019 11:38:22 +0900',
#  'total': 367987,
#  'start': 1,
#  'display': 10,
#  'items': [{'title': '美 전문가 &quot;한일 분쟁 해결 위해 트럼프 직접 개입해야&quot;',
#    'originallink': 'https://www.ytn.co.kr/_ln/0104_201908081133308835',
#    'link': 'https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=104&oid=052&aid=0001328713',
#    'description': "러시아로 '전향'하는 상황을 막아야 한다고 강조했습니다. 또한, 현 상황의 악화를 막기 위해 트럼프 대통령이 개인적으로 문재인 대통령과 <b>아베</b> 총리에게 추가 확대 행동을 자제하도록 촉구해야 한다고 강조했습니다.",
#    'pubDate': 'Thu, 08 Aug 2019 11:33:00 +0900'},
#   {'title': '민예총 &quot;<b>아베</b>정권 사죄 그날까지 항일예술로 싸워 나갈 것&quot;',
#    'originallink': 'http://www.headlinejeju.co.kr/?mod=news&act=articleView&idxno=369698',
#    'link': 'http://www.headlinejeju.co.kr/?mod=news&act=articleView&idxno=369698',
#    'description': '사단법인 한국민족예술단체총연합회과 사단법인 제주민예총은 8일 성명을 내고 &quot;일본 <b>아베</b> 정부의 경제... 것&quot;이라며 &quot;<b>아베</b>정권이 사죄하고 민주주의를 회복하는 그날까지 싸울 것&quot;이라고 밝혔다. 이어 &quot;한국 민족예술인은... ',
#    'pubDate': 'Thu, 08 Aug 2019 11:32:00 +0900'},
#   {'title': "나경원 '우리 일본' 발언에 여야 한목소리로 비판…장제원 ''우리 정치 참 좁...",
#    'originallink': 'http://www.topstarnews.net/news/articleView.html?idxno=655891',
#    'link': 'http://www.topstarnews.net/news/articleView.html?idxno=655891',
#    'description': "이전에 나 원내대표가 <b>아베</b> 정부의 '기 살리기'에 몰두했다는 지적도 이어졌다. 바른미래당 김정화 대변인은... 더불어 이전에 나 원내대표가 이전에 발언한 내용과 관련해서 그를 '나베(나경원+<b>아베</b>)', 친일파 등으로... ",
#    'pubDate': 'Thu, 08 Aug 2019 11:31:00 +0900'},
#   {'title': '[전문]서울시 2부시장 &quot;행안부 요구 대부분 수용…차질없이 진행토록 최선&quot;',
#    'originallink': 'http://www.edaily.co.kr/news/newspath.asp?newsid=02719126622585352',
#    'link': 'https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=018&aid=0004440997',
#    'description': '지금 대한민국은, 역사에 대한 반성 없는 일본 <b>아베</b>정부의 부당한 경제보복에 문재인 대통령과 더불어 온 국민이 각자의 자리에서 총성 없는 전쟁을 하고 있다. 이런 시기에 광화문광장재구조화 사업은 불의에 맞섰던... ',
#    'pubDate': 'Thu, 08 Aug 2019 11:30:00 +0900'},
#   {'title': "&quot;원전사고 정보 공개하라&quot;...'방사능 부메랑' 맞는 日",
#    'originallink': 'https://view.asiae.co.kr/article/2019080811202604033',
#    'link': 'https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=104&oid=277&aid=0004515534',
#    'description': "나아가 국제환경단체 그린피스의 숀 버니 수석 원자력 전문가는 '이코노미스트'에 기고한 글을 통해 &quot;<b>아베</b> 내각과 도쿄전력이 후쿠시마 제1 원전에 쌓인 방사성 오염수 100만t 이상을 태평양에 방류하려고 한다&quot;며 &quot;이... ",
#    'pubDate': 'Thu, 08 Aug 2019 11:30:00 +0900'},
#   {'title': '심상정 정의당 대표 부산 방문',
#    'originallink': 'http://news.knn.co.kr/news/todaynews_read.asp?etime=2019080700067&userid=jskil&newsgubun=politics',
#    'link': 'http://news.knn.co.kr/news/todaynews_read.asp?etime=2019080700067&userid=jskil&newsgubun=politics',
#    'description': '심상정 대표는 일본영사관 인근 평화의 소녀상 앞에서 <b>아베</b> 규탄 정당연설회를 갖고, 한일군사정보보호협정 파기등 한일관계 재정립을 요구했습니다. 또 1965년 한일협정에서 비롯된 불평등한 과거사와 제도를 이번... ',
#    'pubDate': 'Thu, 08 Aug 2019 11:30:00 +0900'},
#   {'title': '[뉴스클릭] - <b>아베</b> 보좌관, &quot;한국은 과거 매춘 관광국&quot;',
#    'originallink': 'http://news.knn.co.kr/news/todaynews_read.asp?etime=2019080700069&userid=yellowtiger&newsgubun=society',
#    'link': 'http://news.knn.co.kr/news/todaynews_read.asp?etime=2019080700069&userid=yellowtiger&newsgubun=society',
#    'description': '#정치면 <b>아베</b> 총리의 측근인 에토 세이이치 총리 보좌관이 일본을 방문한 여야 의원들에게 한국은 과거 매춘 관광국이라는 취지의 발언을 해 충격을 주고 있습니다. 한일관계에 대해 편하게 논의하자며 주선한 자리에서... ',
#    'pubDate': 'Thu, 08 Aug 2019 11:30:00 +0900'},
#   {'title': 'MBC 기자 폭행한 이영훈을 보면서',
#    'originallink': 'http://www.pressian.com/news/article.html?no=252416&utm_source=naver&utm_medium=search',
#    'link': 'https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=110&oid=002&aid=0002099809',
#    'description': 'SNS 공간만 해도 문재인 정부의 상식 부재를 비하하고 <b>아베</b> 정부의 합리성을 옹호하는 이른바 “지식인”들의 글이 서캐처럼 바글바글하다. 하지만 오늘 스마트폰 화면에 떠오른 할머니의 얼굴. 마이크 들고 외치는 저... ',
#    'pubDate': 'Thu, 08 Aug 2019 11:29:00 +0900'},
#   {'title': '평화의 소녀상 앞에 무릎꿇은 <b>아베</b> 퍼포먼스',
#    'originallink': 'http://www.newsis.com/view/?id=NISI20190808_0015479542',
#    'link': 'https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=102&oid=003&aid=0009390287',
#    'description': '광주 북구 평화인간띠잇기추진위원회가 8일 북구청 평화의 소녀상 광장에서 <b>아베</b> 신조 일본 총리를 규탄하는 퍼포먼스를 하고 있다. 2019.08.08.',
#    'pubDate': 'Thu, 08 Aug 2019 11:29:00 +0900'},
#   {'title': '3년 전 겨울 소녀상 지키던 대학생 &quot;한일문제, 일본 시민과 연대 필요&quot;',
#    'originallink': 'https://view.asiae.co.kr/article/2019080811293569876',
#    'link': 'https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=102&oid=277&aid=0004515532',
#    'description': '이 대표는 한일갈등은 당연히 <b>아베</b> 신조 일본 총리의 책임이라고 강조한다. 그는 &quot;한일 청구권협정과 위안부... 역시 <b>아베</b> 정부의 실책이라고 생각한다&quot;고 했다. 일본에 대한 분노가 가득한 상황에서 일본 제품... ',
#    'pubDate': 'Thu, 08 Aug 2019 11:29:00 +0900'}]}

# %%
type(tmp)
# Out:
# dict

# %%
for item in tmp['items']:
    print( '->', item['title'] )
# Out:
# -> 美 전문가 &quot;한일 분쟁 해결 위해 트럼프 직접 개입해야&quot;
# -> 민예총 &quot;<b>아베</b>정권 사죄 그날까지 항일예술로 싸워 나갈 것&quot;
# -> 나경원 '우리 일본' 발언에 여야 한목소리로 비판…장제원 ''우리 정치 참 좁...
# -> [전문]서울시 2부시장 &quot;행안부 요구 대부분 수용…차질없이 진행토록 최선&quot;
# -> &quot;원전사고 정보 공개하라&quot;...'방사능 부메랑' 맞는 日
# -> 심상정 정의당 대표 부산 방문
# -> [뉴스클릭] - <b>아베</b> 보좌관, &quot;한국은 과거 매춘 관광국&quot;
# -> MBC 기자 폭행한 이영훈을 보면서
# -> 평화의 소녀상 앞에 무릎꿇은 <b>아베</b> 퍼포먼스
# -> 3년 전 겨울 소녀상 지키던 대학생 &quot;한일문제, 일본 시민과 연대 필요&quot;

# %%
[ item['title'] for item in tmp['items'] ]
# Out:
# ['美 전문가 &quot;한일 분쟁 해결 위해 트럼프 직접 개입해야&quot;',
#  '민예총 &quot;<b>아베</b>정권 사죄 그날까지 항일예술로 싸워 나갈 것&quot;',
#  "나경원 '우리 일본' 발언에 여야 한목소리로 비판…장제원 ''우리 정치 참 좁...",
#  '[전문]서울시 2부시장 &quot;행안부 요구 대부분 수용…차질없이 진행토록 최선&quot;',
#  "&quot;원전사고 정보 공개하라&quot;...'방사능 부메랑' 맞는 日",
#  '심상정 정의당 대표 부산 방문',
#  '[뉴스클릭] - <b>아베</b> 보좌관, &quot;한국은 과거 매춘 관광국&quot;',
#  'MBC 기자 폭행한 이영훈을 보면서',
#  '평화의 소녀상 앞에 무릎꿇은 <b>아베</b> 퍼포먼스',
#  '3년 전 겨울 소녀상 지키던 대학생 &quot;한일문제, 일본 시민과 연대 필요&quot;']

# %%
tmp['items']
# Out:
# [{'title': '美 전문가 &quot;한일 분쟁 해결 위해 트럼프 직접 개입해야&quot;',
#   'originallink': 'https://www.ytn.co.kr/_ln/0104_201908081133308835',
#   'link': 'https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=104&oid=052&aid=0001328713',
#   'description': "러시아로 '전향'하는 상황을 막아야 한다고 강조했습니다. 또한, 현 상황의 악화를 막기 위해 트럼프 대통령이 개인적으로 문재인 대통령과 <b>아베</b> 총리에게 추가 확대 행동을 자제하도록 촉구해야 한다고 강조했습니다.",
#   'pubDate': 'Thu, 08 Aug 2019 11:33:00 +0900'},
#  {'title': '민예총 &quot;<b>아베</b>정권 사죄 그날까지 항일예술로 싸워 나갈 것&quot;',
#   'originallink': 'http://www.headlinejeju.co.kr/?mod=news&act=articleView&idxno=369698',
#   'link': 'http://www.headlinejeju.co.kr/?mod=news&act=articleView&idxno=369698',
#   'description': '사단법인 한국민족예술단체총연합회과 사단법인 제주민예총은 8일 성명을 내고 &quot;일본 <b>아베</b> 정부의 경제... 것&quot;이라며 &quot;<b>아베</b>정권이 사죄하고 민주주의를 회복하는 그날까지 싸울 것&quot;이라고 밝혔다. 이어 &quot;한국 민족예술인은... ',
#   'pubDate': 'Thu, 08 Aug 2019 11:32:00 +0900'},
#  {'title': "나경원 '우리 일본' 발언에 여야 한목소리로 비판…장제원 ''우리 정치 참 좁...",
#   'originallink': 'http://www.topstarnews.net/news/articleView.html?idxno=655891',
#   'link': 'http://www.topstarnews.net/news/articleView.html?idxno=655891',
#   'description': "이전에 나 원내대표가 <b>아베</b> 정부의 '기 살리기'에 몰두했다는 지적도 이어졌다. 바른미래당 김정화 대변인은... 더불어 이전에 나 원내대표가 이전에 발언한 내용과 관련해서 그를 '나베(나경원+<b>아베</b>)', 친일파 등으로... ",
#   'pubDate': 'Thu, 08 Aug 2019 11:31:00 +0900'},
#  {'title': '[전문]서울시 2부시장 &quot;행안부 요구 대부분 수용…차질없이 진행토록 최선&quot;',
#   'originallink': 'http://www.edaily.co.kr/news/newspath.asp?newsid=02719126622585352',
#   'link': 'https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=018&aid=0004440997',
#   'description': '지금 대한민국은, 역사에 대한 반성 없는 일본 <b>아베</b>정부의 부당한 경제보복에 문재인 대통령과 더불어 온 국민이 각자의 자리에서 총성 없는 전쟁을 하고 있다. 이런 시기에 광화문광장재구조화 사업은 불의에 맞섰던... ',
#   'pubDate': 'Thu, 08 Aug 2019 11:30:00 +0900'},
#  {'title': "&quot;원전사고 정보 공개하라&quot;...'방사능 부메랑' 맞는 日",
#   'originallink': 'https://view.asiae.co.kr/article/2019080811202604033',
#   'link': 'https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=104&oid=277&aid=0004515534',
#   'description': "나아가 국제환경단체 그린피스의 숀 버니 수석 원자력 전문가는 '이코노미스트'에 기고한 글을 통해 &quot;<b>아베</b> 내각과 도쿄전력이 후쿠시마 제1 원전에 쌓인 방사성 오염수 100만t 이상을 태평양에 방류하려고 한다&quot;며 &quot;이... ",
#   'pubDate': 'Thu, 08 Aug 2019 11:30:00 +0900'},
#  {'title': '심상정 정의당 대표 부산 방문',
#   'originallink': 'http://news.knn.co.kr/news/todaynews_read.asp?etime=2019080700067&userid=jskil&newsgubun=politics',
#   'link': 'http://news.knn.co.kr/news/todaynews_read.asp?etime=2019080700067&userid=jskil&newsgubun=politics',
#   'description': '심상정 대표는 일본영사관 인근 평화의 소녀상 앞에서 <b>아베</b> 규탄 정당연설회를 갖고, 한일군사정보보호협정 파기등 한일관계 재정립을 요구했습니다. 또 1965년 한일협정에서 비롯된 불평등한 과거사와 제도를 이번... ',
#   'pubDate': 'Thu, 08 Aug 2019 11:30:00 +0900'},
#  {'title': '[뉴스클릭] - <b>아베</b> 보좌관, &quot;한국은 과거 매춘 관광국&quot;',
#   'originallink': 'http://news.knn.co.kr/news/todaynews_read.asp?etime=2019080700069&userid=yellowtiger&newsgubun=society',
#   'link': 'http://news.knn.co.kr/news/todaynews_read.asp?etime=2019080700069&userid=yellowtiger&newsgubun=society',
#   'description': '#정치면 <b>아베</b> 총리의 측근인 에토 세이이치 총리 보좌관이 일본을 방문한 여야 의원들에게 한국은 과거 매춘 관광국이라는 취지의 발언을 해 충격을 주고 있습니다. 한일관계에 대해 편하게 논의하자며 주선한 자리에서... ',
#   'pubDate': 'Thu, 08 Aug 2019 11:30:00 +0900'},
#  {'title': 'MBC 기자 폭행한 이영훈을 보면서',
#   'originallink': 'http://www.pressian.com/news/article.html?no=252416&utm_source=naver&utm_medium=search',
#   'link': 'https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=110&oid=002&aid=0002099809',
#   'description': 'SNS 공간만 해도 문재인 정부의 상식 부재를 비하하고 <b>아베</b> 정부의 합리성을 옹호하는 이른바 “지식인”들의 글이 서캐처럼 바글바글하다. 하지만 오늘 스마트폰 화면에 떠오른 할머니의 얼굴. 마이크 들고 외치는 저... ',
#   'pubDate': 'Thu, 08 Aug 2019 11:29:00 +0900'},
#  {'title': '평화의 소녀상 앞에 무릎꿇은 <b>아베</b> 퍼포먼스',
#   'originallink': 'http://www.newsis.com/view/?id=NISI20190808_0015479542',
#   'link': 'https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=102&oid=003&aid=0009390287',
#   'description': '광주 북구 평화인간띠잇기추진위원회가 8일 북구청 평화의 소녀상 광장에서 <b>아베</b> 신조 일본 총리를 규탄하는 퍼포먼스를 하고 있다. 2019.08.08.',
#   'pubDate': 'Thu, 08 Aug 2019 11:29:00 +0900'},
#  {'title': '3년 전 겨울 소녀상 지키던 대학생 &quot;한일문제, 일본 시민과 연대 필요&quot;',
#   'originallink': 'https://view.asiae.co.kr/article/2019080811293569876',
#   'link': 'https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=102&oid=277&aid=0004515532',
#   'description': '이 대표는 한일갈등은 당연히 <b>아베</b> 신조 일본 총리의 책임이라고 강조한다. 그는 &quot;한일 청구권협정과 위안부... 역시 <b>아베</b> 정부의 실책이라고 생각한다&quot;고 했다. 일본에 대한 분노가 가득한 상황에서 일본 제품... ',
#   'pubDate': 'Thu, 08 Aug 2019 11:29:00 +0900'}]

# %%
# 연구목표: 주요포털을 통한 뉴스 해드라인 수집 + 언론사명 + 기자명
# 이를 통해 아베에 대한 언론의 긍정/부정에 대한 뉘앙스 분석
################################################################

import urllib.request
import os
import sys
import json

# 네이터 쿼리 인증키 : 일일 쿼터 25,000 ( 아이디가 많으면 검색할 수 있느 횟수 증가 )
Client_ID = '_kYGPWLxEKgbDV0v7Kn3'
Secret    = 'FNDu62I5Md'

# API URL
news_url = 'https://openapi.naver.com/v1/search/news.json'
# 검색키워드를 고정할 것인가? 디비에서 관리해서 가져올 것인가? -> 우린 디비에서 가져오겠다(향후 -> 필요한것들: 마리아 디비, 테이블, 키워드 및 sql과 거기에 따른 코드가 필요함)
keyword    = urllib.parse.quote('아베')


# url 생성(최종 url)
# 함수로 만들기(코드의 함수화)
def makeFullUrlByGet( news_url, start ):
    news_param = 'query=%s&display=%s&start=%s&sort=%s' % (keyword, 100, start, 'date') # start가 계속 업뎃됨
    url = '%s?%s' % (news_url, news_param)  # %s?%s: get 방식
    return url

# 통신이 필요하다 ( 이건 1페이지만 가지고 오는것(풀코드로 한번은 작성해줘야한다))
# 통신 : 최초 1회 전체 데이터를 다 가져온다 => 1~1000가능, 통신을 한다는 행위 자체가 계속 반복한다는 뜻
# 테스트할 때 전체 크기가 커버리면 결과를 확인하는데 너무 오래 걸린다,
# 임의로 5를 부여하여 4번 정도 확인해 본다(샘플링)
results = list() # for문이 돌기전에.
for start in range(1,5): # 1001): for문이 돌때마다 주소를 만들고 통신을 한다
    print( makeFullUrlByGet( news_url, start ) )  # -> 여기까지 구동하면 start 1,2,3,4 가 나오는거 확인
    # 통신 객체 생성
    request = urllib.request.Request( makeFullUrlByGet( news_url, start ) ) # 이 함수는 1페이지 고정이다, 27번줄로 for문 작성 
    # 헤더 설정
    request.add_header("X-Naver-Client-Id", Client_ID)
    request.add_header("X-Naver-Client-Secret", Secret)
    # 실제 통신
    response = urllib.request.urlopen(request)
    # 결과처리 
    
    if(response.getcode() == 200): # 통신성공,  바로 처리하게끔 코드 수정. 
        tmp = json.load(response)
        #print( [ item['title'] for item in tmp['items'] ] )
        results.extend( tmp['items'] )
# Out:
# https://openapi.naver.com/v1/search/news.json?query=%EC%95%84%EB%B2%A0&display=100&start=1&sort=date
# https://openapi.naver.com/v1/search/news.json?query=%EC%95%84%EB%B2%A0&display=100&start=2&sort=date
# https://openapi.naver.com/v1/search/news.json?query=%EC%95%84%EB%B2%A0&display=100&start=3&sort=date
# https://openapi.naver.com/v1/search/news.json?query=%EC%95%84%EB%B2%A0&display=100&start=4&sort=date

# %%
len(results)
# Out:
# 400

# %%
### 수집한 데이터를 데이터베이스에 적제
#데이터를 전처리하지 않고 그대로 디비에 넣겠다
#table생성 및 pandas를 이용한 간단하게 디비에 밀어넣기 구현
#pandas는 있으나, python <-> mariadb간에 통신을 담당할 모듈이 필요
## $conda install pymysql
    # $conda install sqlalchemy

# %%
import pandas as pd

# %%
# 데이터(리스트, 딕셔너리구조,) => DataFrame(팬더스에서 데이터를 다루는 자료구조)
# => sqlalchemy => pymysql => 데이터베이스에 적재

# %%
## 데이터(리스트, 딕셔너리구조) => DataFrame
df_dict = pd.DataFrame.from_dict( results )  # 딕셔너리로부터 
df_dict
# 표 결과물 출력(적제된다) -> sqldb에 넣기가 너무 번거로우니 1줄로 끝내버림
# Out:
#                                            description  \
# 0    러시아로 '전향'하는 상황을 막아야 한다고 강조했습니다. 또한, 현 상황의 악화를 ...
# 1    사단법인 한국민족예술단체총연합회과 사단법인 제주민예총은 8일 성명을 내고 &quot...
# 2    이전에 나 원내대표가 <b>아베</b> 정부의 '기 살리기'에 몰두했다는 지적도 이...
# 3    지금 대한민국은, 역사에 대한 반성 없는 일본 <b>아베</b>정부의 부당한 경제보...
# 4    나아가 국제환경단체 그린피스의 숀 버니 수석 원자력 전문가는 '이코노미스트'에 기고...
# 5    심상정 대표는 일본영사관 인근 평화의 소녀상 앞에서 <b>아베</b> 규탄 정당연설...
# 6    #정치면 <b>아베</b> 총리의 측근인 에토 세이이치 총리 보좌관이 일본을 방문한...
# 7    SNS 공간만 해도 문재인 정부의 상식 부재를 비하하고 <b>아베</b> 정부의 합...
# 8    광주 북구 평화인간띠잇기추진위원회가 8일 북구청 평화의 소녀상 광장에서 <b>아베<...
# 9    이 대표는 한일갈등은 당연히 <b>아베</b> 신조 일본 총리의 책임이라고 강조한다...
# 10   강제동원공동행동, 日 시민단체와 광복절 행사 함께 진행 <b>아베</b>규탄 시민행...
# 11   <b>아베</b> 신조 일본 총리의 경제보복 같은 중대한 사안이 벌어지는데, 그까짓...
# 12   <b>아베</b> 총리가 거의 7년동안 노력해왔던 리플레이션 타격도 큰 영향을 받았...
# 13   침탈하려는 <b>아베</b> 정부의 의도에 분노하면서도 지금의 위기를 가장 현명하게...
# 14   일본의 경제보복과 관련해 일본과의 교류와 사업 전면 중단을 선언하고 극일(克日) 교...
# 15   기고문에서 숀 버니는 “<b>아베</b> 내각과 도쿄전력이 후쿠시마 제1원전에 쌓여...
# 16   일본 <b>아베</b> 신조 최측근인 에토 세이이치 보좌관이 한국 정치인들에게 &q...
# 17   정의당 심상정 대표는 일본이 추가 개별허가품목을 지정하지 않은 것과 관련해 &quo...
# 18   나경원 원내대표는 &quot;<b>아베</b> 일본 총리가 한일청구권협상 언급하며 ...
# 19   [기자] 민주당은 한일 경제전에서 반드시 승리할 것이라고 강조하며 <b>아베</b>...
# 20   자행하는 <b>아베</b>정권 사죄하라&quot; 등의 구호를 힘껏 외치며 홍보물을...
# 21   앞서 괴산군 주민자치위원협의회는 <b>아베</b>정부의 이번 조치에 대해 강력히 대...
# 22   특히 최근 일본 <b>아베</b> 총리가 이번 경제보복 조치를 부정하면서도 그 배경...
# 23   일본 <b>아베</b> 정부의 태도 변화를 이끌어낼 수 있는 관건은 우리의 압박 강...
# 24   공무원노조가 7일 오전 주한일본대사관 앞에서 <b>아베</b> 규탄과 지소미아 폐기...
# 25   윤종신은 최근 SNS를 통해 일본 걸그룹 AKB48 출신 다케우치 미유와와 ‘월간 ...
# 26   공무원노조 법원본부가 7일 오전 서울 종로구 일본대사관 앞에서 '대법원 강제징용 판...
# 27   또한 <b>아베</b> 신조(安倍晋三) 일본 총리를 향해서도 &quot;변화와 양보...
# 28   나 원내대표는 일본정부가 특정 품목을 개별 허가 대상에 추가하지 않은 것에 대해 &...
# 29   그러면서 &quot;거듭 강조하지만 일본 <b>아베</b> 정부의 도발을 막을 방안...
# ..                                                 ...
# 370  8일 오전 서울 중구 프란치스코 교육회관에서 강제동원 문제해결과 대일과거청산을 위한...
# 371  “<b>아베</b> 총리·한국 정부 모두 양보 의지 보여야” 조국 법무부장관 기용설...
# 372  이윤영 동학혁명연구소장 1인시위 “혁명정신 계승…전봉준 장군 복장” 일본 <b>아베...
# 373  정세균 위원장은 이날 회의를 주재하며 “<b>아베</b> 정부의 무분별하고 일방적 ...
# 374  엄마부대라고 하는 단체의 주옥순 대표가 <b>아베</b> 수상에게 '사죄'를 했습니...
# 375  <b>아베</b> 신조 정부가 한일 경제보복 조치와 관련해 일단 속도조절에 들어간 ...
# 376  그는 또한 <b>아베</b> 신조(安倍晋三) 일본 총리를 향해서도 &quot;변화와...
# 377  숀 버니 씨는 &quot;<b>아베</b> 정부가 후쿠시마 제1원전에 쌓여 있는 고...
# 378  이는 수출규제 대상이라도 절차에 문제가 없다면 수출할 수 있다는 <b>아베</b> ...
# 379  일본 <b>아베</b> 정권의 무역 보복조치에 맞서 100억원 규모의 긴급자금 편성...
# 380  &quot;규제, 금수조치 아냐…정당한 거래엔 허가 내주는 것 보여줘&quot; 강...
# 381  지난 3일 오후 7시 서울 종로구 옛 일본 대사관 앞에서 ‘<b>아베</b> 규탄 ...
# 382  정세균 더불어민주당 소재·부품·장비 인력발전 특별위원회 위원장은 8일 국회에서 첫 ...
# 383  하승수 변호사 “<b>아베</b> 최측근 ‘매춘 관광국’ 망언 사과 받아야“ “매춘...
# 384  거듭 강조하지만, 일본 <b>아베</b>정부의 도발을 단기적으로 좌절시킬 수 있는 ...
# 385  안 부의장은 “<b>아베</b>정권은 위안부와 강제징병 등 반인륜적 범죄로 전 세계...
# 386  이들은 &quot;과거사에 대한 반성 없는 <b>아베</b>정권을 규탄하고 일본의 ...
# 387  com 이 원내대표는 그러면서 “정부는 주요 기업들과 면밀히 상황 점검하며 대화해왔...
# 388  회의에 참석한 이·통장 연합회 임원 50여명은 일본 <b>아베</b>정권의 반인권적...
# 389  “한국손님이 하루에 20개 팀이 찾았으나 최근 2~3팀으로 줄었다&quot;고 말했...
# 390  8일 오전 서울 중구 프란치스코 교육회관에서 열린 광복 74주년 강제동원 문제 해결...
# 391  기고문에서는 &quot;<b>아베</b> 내각과 도쿄전력이 후쿠시마 제1원전에 쌓여...
# 392  8일 오전 서울 중구 프란치스코 교육회관에서 열린 광복 74주년 강제동원 문제 해결...
# 393  <b>아베</b> 이유 제시 못해 - 상응조치로 日 백색국가 제외? 논의는 하되 공...
# 394  8일 오전 서울 중구 프란치스코 교육회관에서 열린 광복 74주년 강제동원 문제 해결...
# 395  <b>아베</b>신조의 일본 정부는 자신들이 우위에 있다고 판단하는 기초소재 및 부...
# 396  또한 <b>아베</b> 신조 총리를 비롯한 일본 정부의 끈질긴 역사 왜곡에 대해 김...
# 397  민·관 기업이 총력 대응하는 만큼 우리 경제는 지금의 비상한 상황 이겨내고 한층 더...
# 398  &quot;개헌-전쟁을 향한 <b>아베</b> 정권 타도!&quot; -대한국 수출...
# 399  닛케이신문은 수출 규제 대상이라도 절차에 문제가 없으면 수출할 수 있다고 밝힌 <b...
#
#                                                   link  \
# 0    https://news.naver.com/main/read.nhn?mode=LSD&...
# 1    http://www.headlinejeju.co.kr/?mod=news&act=ar...
# 2    http://www.topstarnews.net/news/articleView.ht...
# 3    https://news.naver.com/main/read.nhn?mode=LSD&...
# 24   공무원노조 &quot;NO <b>아베</b>, 공직 내 일제 잔재 청산 나설 것&q...
# 25      [팝컬처]한일갈등 대중문화 영향은···일본 내 한류 OK, 한국 방송가서 일본...
# 26    법원공무원 &quot;대법판결 정당, <b>아베</b>정부 사과하고 배상해야&quot;
# 27    나경원 &quot;파국으로 가던 한일 갈등 잠시 숨고르기...지금이 골든타임&quot;
# 28   나경원 &quot;조국 법무부 장관 지명, 신독재화 완성위한 검찰 도구화 선언&quot;
# 29      오신환 &quot;文 정부, 구체적 해법 없이 아무말 대잔치로 상황 악화&quot;
# ..                                                 ...
# 370                       <b>아베</b> 정권은 강제동원 피해자에 사과하라
# 371           ‘우리 일본’ 논란 나경원 “한일 갈등 골든타임…말꼬리 잡을 때 아니야”
# 372               상투적인 1인 시위 가라…일 불매운동에 전봉준 장군 ‘상투’ 등장
# 373                  민주, 日경제침략 피해산업 자립 특위 가동...위원장 정세균
# 374  전우용 &quot;주옥순 대표 발언...역사공부 30년 넘게 이런 경우 못 봤어&q...
# 375         일본, 삼성전자에 EUV포토레지스트 수출 허용...'경제보복' 이후 첫 허가
# 376         나경원 &quot;韓日갈등 풀 '골든타임'…반일선동 말고 외교해법&quot;
# 377       그린피스 &quot;日 방사능 오염수 100만톤 방류 계획…한국 위험&quot;
# 378                    일본, 규제 품목 첫 수출허가… 정부는 '탈일본화' 가속
# 379                       경기도의회 '일 수출규제' 피해기업 지원 뒷북 논란
# 380        日관방 &quot;안보우려 없는 거래 확인돼 韓 수출 첫 승인&quot; 주장
# 381        '숨통을 쥐었다 폈다' 日, 일부 수출허가에 &quot;숨은 의도는&quot;
# 382     정세균 &quot;감정적 처방보다 냉정한 자세로&quot; 與 반일 과열에 '제동'
# 383                       “매춘이라는 단어를 쓰고, 위안부 문제를 거론해?”
# 384                            [발언자료] 제52차 원내정책회의 모두발언
# 385                  경기도의회 안혜영 부의장, 일본경제보복 철회 1인 시위 나서
# 386         인천 남동구 주민자치협의회, 일본 경제침략 규탄하며 'NO JAPAN' 동참
# 387            이인영, 황교안에 &quot;색깔론 입각해 경제 불안감 조성&quot;
# 388                     【논산】논산시이통장연합회, 일본제품 불매운동 동참할 것
# 389  한국손님 하루 20개 팀서 최근 2~3팀으로 '뚝'... 한일 경제전쟁 관광업계에 ...
# 390                                  '<b>아베</b>를 규탄한다'
# 391                    해수부 “후쿠시마 방사성 오염수 방류 관련 면밀히 대응”
# 392                                  '<b>아베</b>를 규탄한다'
# 393  [시선집중] 송기호 &quot;<b>아베</b> 선택의 폭 좁아.. 수출규제 철회 ...
# 394                                  '<b>아베</b>를 규탄한다'
# 395    [서동윤의 역사 브리핑] 조선의 기억 돌아보기 - 일본의 '조선 인삼' 밀반출 ...
# 396                     ‘김복동’ 드디어 개봉, ‘우리가 증인이다’ 영상 공개
# 397      이인영, 韓·日 경제전 “우리 경제의 펀더멘탈은 굳건하다. 전쟁은 반드시 승...
# 398                                 깍뚜기와 다꾸앙, 김치와 우메보시
# 399                  규제 한 달여만…일본, 반도체 핵심소재 일부 품목 수출 허가
#
# [400 rows x 5 columns]

# %%
# 상위값 확인
df_dict.head(2)
# Out:
#                                          description  \
# 0  러시아로 '전향'하는 상황을 막아야 한다고 강조했습니다. 또한, 현 상황의 악화를 ...
# 1  사단법인 한국민족예술단체총연합회과 사단법인 제주민예총은 8일 성명을 내고 &quot...
#
#                                                 link  \
# 0  https://news.naver.com/main/read.nhn?mode=LSD&...
# 1  http://www.headlinejeju.co.kr/?mod=news&act=ar...
#
#                                         originallink  \
# 0  https://www.ytn.co.kr/_ln/0104_201908081133308835
# 1  http://www.headlinejeju.co.kr/?mod=news&act=ar...
#
#                            pubDate  \
# 0  Thu, 08 Aug 2019 11:33:00 +0900
# 1  Thu, 08 Aug 2019 11:32:00 +0900
#
#                                                title
# 0          美 전문가 &quot;한일 분쟁 해결 위해 트럼프 직접 개입해야&quot;
# 1  민예총 &quot;<b>아베</b>정권 사죄 그날까지 항일예술로 싸워 나갈 것&quot;

# %%
# 히위값 확인
df_dict.tail(2)
# Out:
#                                            description  \
# 398  &quot;개헌-전쟁을 향한 <b>아베</b> 정권 타도!&quot; -대한국 수출...
# 399  닛케이신문은 수출 규제 대상이라도 절차에 문제가 없으면 수출할 수 있다고 밝힌 <b...
#
#                                                   link  \
# 398  http://www.nongaek.com/news/articleView.html?i...
# 399  http://speconomy.com/news/newsview.php?ncode=1...
#
#                                           originallink  \
# 398  http://www.nongaek.com/news/articleView.html?i...
# 399  http://speconomy.com/news/newsview.php?ncode=1...
#
#                              pubDate                              title
# 398  Thu, 08 Aug 2019 10:32:00 +0900                 깍뚜기와 다꾸앙, 김치와 우메보시
# 399  Thu, 08 Aug 2019 10:30:00 +0900  규제 한 달여만…일본, 반도체 핵심소재 일부 품목 수출 허가

# %%
# 데이터 크기
df_dict.shape
# Out:
# (400, 5)

# %%
# db에 넣기
import pymysql
from sqlalchemy import create_engine
import pandas.io.sql as pSql
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-72-e4f3aaa24e58> in <module>()
#       1 # db에 넣기
# ----> 2 import pymysql
#       3 from sqlalchemy import create_engine
#       4 import pandas.io.sql as pSql
#
# ModuleNotFoundError: No module named 'pymysql'

# %%
# 연결
db_url = 'mysql+pymysql://root:mysql@localhost/python_db'  # root: id , myslq: pw

# %%
# 데이터 프레임의 데이터의 컬럼 목록 확인 -> 마리아디비 열 추가할때 사용하기 요긴함
df_dict.columns

# %%
# 엔진생성(절차)
engine = create_engine( db_url, encoding='utf8')

# %%
# 실연결
conn = engine.connect()

# %%
# 데이터 삽입
# name : 파라미터 직접 설정, tbl_navernews: 마리아db 테이블이름 
# index : 뉴스가져왔을때 인덱스가 생성되는데 이걸 데이터로 인정해줄건지 안할건지 결정(true, false)
df_dict.to_sql( name = 'tbl_navernews', con = conn, if_exists='append', index = False )

# %%
# 해제
conn.close()

# %%
import time

# %%
time.sleep(1)

# %%
df_dict.iloc[0]['title']
